# %% [markdown]
# ### Importação de Módulos e Arquivos e Tratamento das bases

# %%
import pandas as pd

funcionarios_df = pd.read_csv('CadastroFuncionarios.csv', sep=';', decimal=',')
clientes_df = pd.read_csv('CadastroClientes.csv', sep=';', decimal=',')
servicos_df = pd.read_excel('BaseServiçosPrestados.xlsx')

#retirei as colunas estado civil e cargo da tabela funcionários
funcionarios_df = funcionarios_df.drop(['Estado Civil', 'Cargo'], axis=1)

display(funcionarios_df)
display(clientes_df)
display(servicos_df)
# Out:
#      ID Funcionário           Nome Completo  Salario Base  Impostos  \
# 0                 1        Gabriel Mesquita         21910   10955.0
# 1                 2             João Haddad          5404    2702.0
# 2                 3  Amanda Marques Ribeiro         16066    8033.0
# 3                 4         Guilherme Nunez         21305   10652.5
# 4                 5           Adelino Gomes          5098    2549.0
# ..              ...                     ...           ...       ...
# 109             143   Renan Scharnhorst Ott         10793    5396.5
# 110             144      Lucas Brum Pereira          4048    2024.0
# 111             148            Caio Stellet         24596   12298.0
# 112             149          Fernanda Rocha          5078    2539.0
# 113             150            Eduardo Brum         15939    7969.5
#
#      Beneficios   VT      VR            Area
# 0        4382.0  242  719.04       Operações
# 1        1080.8  154  574.56       Logística
# ...

# %% [markdown]
# ### 1 - Cálculo da Folha Salarial

# %%
funcionarios_df['Salario Total'] = funcionarios_df['Salario Base'] + funcionarios_df['Impostos'] + funcionarios_df['Beneficios'] + funcionarios_df['VT'] + funcionarios_df['VR']
print('O valor total da folha salarial mensal é de R${:,}'.format(funcionarios_df['Salario Total'].sum()))
# Out:
# O valor total da folha salarial mensal é de R$2,717,493.22

# %% [markdown]
# ### 2 - Faturamento da Empresa

# %%
faturamentos_df = servicos_df[['ID Cliente', 'Tempo Total de Contrato (Meses)']].merge(clientes_df[['ID Cliente', 'Valor Contrato Mensal']], on='ID Cliente')
faturamentos_df['Faturamento Total'] = faturamentos_df['Tempo Total de Contrato (Meses)'] * faturamentos_df['Valor Contrato Mensal']
#display(faturamentos_df)
print('O valor total do faturamento total da empresa é de R${:,}'.format(faturamentos_df['Faturamento Total'].sum()))
# Out:
# O valor total do faturamento total da empresa é de R$5,519,160

# %% [markdown]
# ### 3 - Percentual de Funcionários que Fecharam Contrato

# %%
qtde_funcionarios_fecharam_contrato = len(servicos_df['ID Funcionário'].unique())
qtde_funcionarios_total = len(funcionarios_df['ID Funcionário'])

print('O percentual de funcionários que fecharam contratos é {:.2%}'.format(qtde_funcionarios_fecharam_contrato / qtde_funcionarios_total))
# Out:
# O percentual de funcionários que fecharam contratos é 86.84%

# %% [markdown]
# ### 4 - Quantidade de Contratos por Área

# %%
contratos_area_df = servicos_df[['ID Funcionário']].merge(funcionarios_df[['ID Funcionário', 'Area']], on='ID Funcionário')

qtde_contratos_area = contratos_area_df['Area'].value_counts()
print('Contratos por área:')
print(qtde_contratos_area)
qtde_contratos_area.plot(kind='bar')
# Out:
# Contratos por área:
# Administrativo    63
# Operações         48
# Comercial         44
# Financeiro        42
# Logística         40
# Name: Area, dtype: int64
# <AxesSubplot:>
